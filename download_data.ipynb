# %%
import os
import json 
import logging

logging.basicConfig(
    filename='log/app.log',            # Specify the log file name
    level=logging.DEBUG,           # Set the log level (DEBUG, INFO, WARNING, ERROR, CRITICAL)
    format='%(asctime)s - %(levelname)s - %(message)s'  # Set the log format
)

# Load the environment configuration JSON data
json_path = 'env_config.json'
with open(json_path, 'r') as file:
    env_config = json.load(file)

hf_home = env_config['HF_HOME']
# Set the HF_HOME environment variable
os.environ['HF_HOME'] = hf_home
# Set the access token to huggingface hub
access_token = env_config['access_token']
os.environ['HUGGINGFACE_HUB_TOKEN'] = access_token

# %%
from datasets import load_dataset,load_metric

dataset_train = load_dataset('imagenet-1k', split='train', streaming=False, token=access_token, trust_remote_code=True)
# Out:
# /afs/crc.nd.edu/user/d/dpan/.local/lib/python3.11/site-packages/datasets/load.py:1461: FutureWarning: The repository for ILSVRC/imagenet-1k contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/ILSVRC/imagenet-1k
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# Cell In[3], line 3
#       1 from datasets import load_dataset,load_metric
# ----> 3 dataset = load_dataset("ILSVRC/imagenet-1k", access_token=access_token)['train']
#
# File ~/.local/lib/python3.11/site-packages/datasets/load.py:2556, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, ignore_verifications, keep_in_memory, save_infos, revision, token, use_auth_token, task, streaming, num_proc, storage_options, trust_remote_code, **config_kwargs)
#    2551 verification_mode = VerificationMode(
#    2552     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    2553 )
#    2555 # Create a dataset builder
# -> 2556 builder_instance = load_dataset_builder(
#    2557     path=path,
#    2558     name=name,
#    2559     data_dir=data_dir,
#    2560     data_files=data_files,
#    2561     cache_dir=cache_dir,
#    2562     features=features,
#    2563     download_config=download_config,
#    2564     download_mode=download_mode,
#    2565     revision=revision,
#    2566     token=token,
#    2567     storage_options=storage_options,
#    2568     trust_remote_code=trust_remote_code,
#    2569     _require_default_config_name=name is None,
#    2570     **config_kwargs,
#    2571 )
#    2573 # Return iterable dataset in case of streaming
#    2574 if streaming:
#
# File ~/.local/lib/python3.11/site-packages/datasets/load.py:2228, in load_dataset_builder(path, name, data_dir, data_files, cache_dir, features, download_config, download_mode, revision, token, use_auth_token, storage_options, trust_remote_code, _require_default_config_name, **config_kwargs)
#    2226     download_config = download_config.copy() if download_config else DownloadConfig()
#    2227     download_config.storage_options.update(storage_options)
# -> 2228 dataset_module = dataset_module_factory(
#    2229     path,
#    2230     revision=revision,
#    2231     download_config=download_config,
#    2232     download_mode=download_mode,
#    2233     data_dir=data_dir,
#    2234     data_files=data_files,
#    2235     cache_dir=cache_dir,
#    2236     trust_remote_code=trust_remote_code,
#    2237     _require_default_config_name=_require_default_config_name,
#    2238     _require_custom_configs=bool(config_kwargs),
#    2239 )
#    2240 # Get dataset builder class from the processing script
#    2241 builder_kwargs = dataset_module.builder_kwargs
#
# File ~/.local/lib/python3.11/site-packages/datasets/load.py:1879, in dataset_module_factory(path, revision, download_config, download_mode, dynamic_modules_path, data_dir, data_files, cache_dir, trust_remote_code, _require_default_config_name, _require_custom_configs, **download_kwargs)
#    1874             if isinstance(e1, FileNotFoundError):
#    1875                 raise FileNotFoundError(
#    1876                     f"Couldn't find a dataset script at {relative_to_absolute_path(combined_path)} or any data file in the same directory. "
#    1877                     f"Couldn't find '{path}' on the Hugging Face Hub either: {type(e1).__name__}: {e1}"
#    1878                 ) from None
# -> 1879             raise e1 from None
#    1880 else:
#    1881     raise FileNotFoundError(
#    1882         f"Couldn't find a dataset script at {relative_to_absolute_path(combined_path)} or any data file in the same directory."
#    1883     )
#
# File ~/.local/lib/python3.11/site-packages/datasets/load.py:1852, in dataset_module_factory(path, revision, download_config, download_mode, dynamic_modules_path, data_dir, data_files, cache_dir, trust_remote_code, _require_default_config_name, _require_custom_configs, **download_kwargs)
#    1843             pass
#    1844     # Otherwise we must use the dataset script if the user trusts it
#    1845     return HubDatasetModuleFactoryWithScript(
#    1846         path,
#    1847         revision=revision,
#    1848         download_config=download_config,
#    1849         download_mode=download_mode,
#    1850         dynamic_modules_path=dynamic_modules_path,
#    1851         trust_remote_code=trust_remote_code,
# -> 1852     ).get_module()
#    1853 else:
#    1854     return HubDatasetModuleFactoryWithoutScript(
#    1855         path,
#    1856         revision=revision,
#    (...)
#    1860         download_mode=download_mode,
#    1861     ).get_module()
#
# File ~/.local/lib/python3.11/site-packages/datasets/load.py:1469, in HubDatasetModuleFactoryWithScript.get_module(self)
#    1461     warnings.warn(
#    1462         f"The repository for {self.name} contains custom code which must be executed to correctly "
#    1463         f"load the dataset. You can inspect the repository content at https://hf.co/datasets/{self.name}\n"
#    (...)
#    1466         FutureWarning,
#    1467     )
#    1468 # get script and other files
# -> 1469 local_path = self.download_loading_script()
#    1470 dataset_infos_path = self.download_dataset_infos_file()
#    1471 dataset_readme_path = self.download_dataset_readme_file()
#
# File ~/.local/lib/python3.11/site-packages/datasets/load.py:1429, in HubDatasetModuleFactoryWithScript.download_loading_script(self)
#    1427 if download_config.download_desc is None:
#    1428     download_config.download_desc = "Downloading builder script"
# -> 1429 return cached_path(file_path, download_config=download_config)
#
# File ~/.local/lib/python3.11/site-packages/datasets/utils/file_utils.py:190, in cached_path(url_or_filename, download_config, **download_kwargs)
#     186     url_or_filename = strip_protocol(url_or_filename)
#     188 if is_remote_url(url_or_filename):
#     189     # URL, so get it from the cache (downloading if necessary)
# --> 190     output_path = get_from_cache(
#     191         url_or_filename,
#     192         cache_dir=cache_dir,
#     193         force_download=download_config.force_download,
#     194         proxies=download_config.proxies,
#     195         resume_download=download_config.resume_download,
#     196         user_agent=download_config.user_agent,
#     197         local_files_only=download_config.local_files_only,
#     198         use_etag=download_config.use_etag,
#     199         max_retries=download_config.max_retries,
#     200         token=download_config.token,
#     201         ignore_url_params=download_config.ignore_url_params,
#     202         storage_options=download_config.storage_options,
#     203         download_desc=download_config.download_desc,
#     204     )
#     205 elif os.path.exists(url_or_filename):
#     206     # File, and it exists.
#     207     output_path = url_or_filename
#
# File ~/.local/lib/python3.11/site-packages/datasets/utils/file_utils.py:589, in get_from_cache(url, cache_dir, force_download, proxies, etag_timeout, resume_download, user_agent, local_files_only, use_etag, max_retries, token, use_auth_token, ignore_url_params, storage_options, download_desc)
#     587 _raise_if_offline_mode_is_enabled(f"Tried to reach {url}")
#     588 if head_error is not None:
# --> 589     raise ConnectionError(f"Couldn't reach {url} ({repr(head_error)})")
#     590 elif response is not None:
#     591     raise ConnectionError(f"Couldn't reach {url} (error {response.status_code})")
#
# ConnectionError: Couldn't reach https://huggingface.co/datasets/ILSVRC/imagenet-1k/resolve/main/imagenet-1k.py (ConnectionError('Unauthorized for URL https://huggingface.co/datasets/ILSVRC/imagenet-1k/resolve/main/imagenet-1k.py. Please use the parameter `token=True` after logging in with `huggingface-cli login`'))
